# %%
from sklearn import datasets
from sklearn import linear_model
from sklearn.cross_validation import cross_val_predict
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lr = linear_model.LinearRegression()

boston = datasets.load_boston()
y = boston.target
print y.shape
# Out:
# (506,)

# %%
predicted = cross_val_predict(lr, boston.data, boston.target, cv=10)

# %%
fig, ax = plt.subplots()
ax.scatter(y, predicted)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=1)
fig.show()
# Out:
# /home/prakash/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
